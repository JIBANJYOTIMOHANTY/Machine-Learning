# %%
import streamlit as st
import pandas as pd
import numpy as np

st.title("Hello Streamlit!")

# Display a text element
st.write("This is a simple Streamlit app.")


# Create a simple DataFrame and display it
df = pd.DataFrame(
    {
        'first column' : [1,2,3,4],
        'second column': [10, 20, 30, 40]
    }
)

# Display the DataFrame in the app
st.write("Here is the dataframe:")
st.write(df)

#Create a line chart using the DataFrame
chart_data = pd.DataFrame(
    np.random.randn(20, 3),
    columns = ['a', 'b', 'c']
)
st.line_chart(df)
# Out:
# 2025-05-01 13:12:51.842 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 13:12:52.483
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run d:\Machine Learning\venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-05-01 13:12:52.485 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 13:12:52.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 13:12:52.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 13:12:52.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 13:12:52.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 13:12:52.515 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 13:12:52.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 13:12:53.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 13:12:53.409 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
