# %%
import threading
import time

def print_numbers():
    for i in range(5):
        print(f"Number : {i}")
        
def print_letters():
    for letter in "abcde":
        print(f"Letter : {letter}")
        
print_numbers()
print()
print_letters()
# Out:
# Number : 0
# Number : 1
# Number : 2
# Number : 3
# Number : 4
#
# Letter : a
# Letter : b
# Letter : c
# Letter : d
# Letter : e
