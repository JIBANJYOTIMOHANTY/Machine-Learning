# %%
def convert_tempr(temp, unit):
    if unit == 'C':
        return (temp * 9 / 5) + 32
    elif unit == 'F':
        return (temp - 32) * 5 / 9;
    else:
        return None
print(convert_tempr(100, 'C'))
print(convert_tempr(212, 'F'))
# Out:
# 212.0
# 100.0

# %%
def isStrongPassword(password):
    if len(password) < 8:
        return False;
    if not any(char.isdigit() for char in password):
        return False;
    if not any(char.isupper() for char in password):
        return False;
    if not any(char.islower() for char in password):
        return False;
    if not any (char in "!@#$%^&*()" for char in password):
        return False;
    return True;
print(isStrongPassword("Aplha@123"))
print(isStrongPassword("alpha@123"))
# Out:
# True
# False

# %%
cart = [
    {
        "name" : "apple",
        "price" : 1.2,
        "quantity" : 5
    },
    {
        "name" : "banana",
        "price" : 0.5,
        "quantity" : 10
    },
    {
        "name" : "orange",
        "price" : 0.8,
        "quantity" : 8
    }
]

def calculate_total(cart):
    total = 0;
    for i in cart:
        total += i["price"] * i["quantity"];
    return total;
print(calculate_total(cart))
# Out:
# 17.4

# %%
def isPalindrome(word):
    word = word.lower().replace(" ", "");
    return word == word[::-1];
print(isPalindrome("wow"))
# Out:
# True

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1;
    else: 
        return n * factorial(n - 1);
print(factorial(5))
# Out:
# 120
