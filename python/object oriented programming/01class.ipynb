# %%
class Car:
    pass
audi = Car()
bmw = Car()
print(type(audi))
print(type(bmw))
print(audi)
print(bmw)
# Out:
# <class '__main__.Car'>
# <class '__main__.Car'>
# <__main__.Car object at 0x0000017364BF3E30>
# <__main__.Car object at 0x0000017364C19EE0>

# %%
tata = Car()
tata.doors = 4
print(tata.doors)
# Out:
# 4

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
class people:
    def __init__(self, name, age):
        self.name = name;
        self.age  = age
        
people1 = people("jiban", 22)
print(people1)
print(people1.name)
print(people1.age)
# Out:
# <__main__.people object at 0x0000017364D8B020>
# jiban
# 22

# %%
people2 = people("manoj", 55)
print(people2)
print(people2.name)
print(people2.age)
# Out:
# <__main__.people object at 0x0000017364D69EE0>
# manoj
# 55

# %%
class Lion:
    def __init__(self, name, age):
        self.name = name
        self.age  = age
    
    def hungry(self):
        print(f"{self.name} is hungry")
        pass
        
lion1 = Lion("Alpha1", 23)
print(lion1)
lion1.hungry()
lion2 = Lion("Alpha2", 26)
lion2.hungry()
# Out:
# <__main__.Lion object at 0x0000017364D69880>
# Alpha1 is hungry
# Alpha2 is hungry

# %%
class BankAccount:
    def __init__(self, owner, balance = 0):
        self.owner = owner
        self.balance = balance
        
    def deposit(self, amount):
        self.balance += amount;
        print(f"{amount} is deposited. New balance is : {self.balance}")
        
    def widhdraw(self, amount):
        if(amount > self.balance):
            print("!!!!! Insufficient Funds !!!!!")
        else :
            self.balance -= amount
            print(f"New balance is : {self.balance}")
            
    def getBalance(self):
        print(f"Balance is : {self.balance}")
        
account = BankAccount("Jiban", 10000)
account.deposit(5000)
account.widhdraw(1000)
account.getBalance()
# Out:
# 5000 is deposited. New balance is : 15000
# New balance is : 14000
# Balance is : 14000
