# %%
class Car:
    def __init__(self, make, model, year):
        self.make = make;
        self.model = model;
        self.year = year;
car = Car('Toyota', 'Camry', 2020)
print(car.make, car.model, car.year)
# Out:
# Toyota Camry 2020

# %%
class Car:
    def __init(self, make, model, year):
        self.make = make;
        self.model = model
        self.year = year;

    def start_Engine(self):
        print("Engine started...")
        
car = Car()
car.start_Engine()
# Out:
# Engine started...

# %%
class Student:
    def __init__(self, name, age):
        self.name = name;
        self.age  = age;
student = Student("Jiban", 22)
print(student.name, student.age)
# Out:
# Jiban 22

# %%
class Person:
    def __init__(self, name, age):
        self.name = name;
        self.age  = age;
        
class Employee(Person):
    def __init__(self, name, age, employeeId):
        super().__init__(name, age)
        self.employeeId = employeeId
        
employee = Employee('Alice', 30, 'E123')
print(employee.name, employee.age, employee.employeeId)
# Out:
# Alice 30 E123

# %%
class Employee(Person):
    def __init__(self, name, age, employeeId):
        super().__init__(name, age);
        self.employeeId = employeeId
    
    def __str__(self):
        return f"Employee(name : {self.name}, Age: {self.age}), Employee ID : {self.employeeId}"
employee = Employee('Alice', 30, 'E123')
print(employee)
# Out:
# Employee(name : Alice, Age: 30), Employee ID : E123

# %%
class Address:
    def __init__(self, street, city, zipcode):
        self.street = street;
        self.city = city;
        self.zipcode = zipcode
        
class Person:
    def __init__(self, address):
        self.address = address
        
address = Address("42 Mouza", "Cuttack", "754112")
person  = Person(address);
print(person)
print(person.address.street, person.address.city, person.address.zipcode)
# Out:
# <__main__.Person object at 0x000001ADFE550620>
# 42 Mouza Cuttack 754112

# %%
class Counter:
    count = 0;
    def __init__(self):
        Counter.count += 1
        
    @classmethod
    def getCount(self):
        return self.count;
    
count1 = Counter()
count2 = Counter()
count3 = Counter()
print(Counter.getCount())
# Out:
# 3

# %%
import math
class MathOperations:
    @staticmethod
    def sqrt(x):
        return math.sqrt(x)
    
print(MathOperations.sqrt(16))
# Out:
# 4.0

# %%
class Rectangle:
    def __init__(self, length, breadth):
        self._length = length
        self._breadth = breadth
        
    @property
    def length(self):
        return self._length

    @length.setter
    def length(self, length):
        self._length = length

    @property
    def width(self):
        return self._breadth

    @width.setter
    def width(self, width):
        self._breadth = width
        
rect = Rectangle(10, 5)
print(rect.length, rect.width)  # 10 5
rect.length = 15
rect.width = 7
print(rect.length, rect.width)  # 15 7
# Out:
# 10 5
# 15 7
