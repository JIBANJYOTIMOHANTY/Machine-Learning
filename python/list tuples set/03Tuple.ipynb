# %%
list1 = list();
tupl1 = tuple();
print(type(list1))
print(type(tupl1))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
numbers = (1, 2, 3, 4, 5, 6)

# %%
print(numbers.count(1))
print(numbers.index(3))
# Out:
# 1
# 2

# %%
package = (1, "Hello", 3.14)
print(package)
# Out:
# (1, 'Hello', 3.14)

# %%
a,b,c = package
print(a)
print(b)
print(c)
# Out:
# 1
# Hello
# 3.14

# %%
numbers = (1, 2, 3, 4, 5, 6)
first, *middle, last = numbers
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
nested_tuple = ((1, 2, 3), ("a", "b", "c"), (True, False))
print(nested_tuple[0])
print(nested_tuple[1][2])
# Out:
# (1, 2, 3)
# c

# %%
for i in nested_tuple:
    for j in i:
        print(j, end=" ")
    print()
# Out:
# 1 2 3
# a b c
# True False
