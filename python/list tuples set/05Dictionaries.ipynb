# %%
student = {
    "name" : "Jiban Jyoti Mohanty",
    "age"  : 22, 
    "grade" : "A",
}
print(student)
print(type(student))
# Out:
# {'name': 'Jiban Jyoti Mohanty', 'age': 22, 'grade': 'A'}
# <class 'dict'>

# %%
student = {
    "name" : "Jiban Jyoti Mohanty",
    "age"  : 22, 
    "grade" : "A",
    "grade" : "A+",
}
print(student)
print(student["name"])
print(student.get("name"))
print(student.get("age"))
print(student.get("grade"))
print(student.get("lastName"))
print(student.get("lastName", "Not Found"))
# Out:
# {'name': 'Jiban Jyoti Mohanty', 'age': 22, 'grade': 'A+'}
# Jiban Jyoti Mohanty
# Jiban Jyoti Mohanty
# 22
# A+
# None
# Not Found

# %%
student["city"] = "Cuttack"
print(student)
# Out:
# {'name': 'Jiban Jyoti Mohanty', 'age': 22, 'grade': 'A+', 'city': 'Cuttack'}

# %%
del student["grade"]
print(student)
# Out:
# {'name': 'Jiban Jyoti Mohanty', 'age': 22, 'city': 'Cuttack'}

# %%
key = student.keys()
values = student.values()
print(key)
print(values)
# Out:
# dict_keys(['name', 'age', 'city'])
# dict_values(['Jiban Jyoti Mohanty', 22, 'Cuttack'])

# %%
student2 = student
print(student)
print(student2)
# Out:
# {'name': 'Jiban Jyoti Mohanty', 'age': 22, 'city': 'Cuttack'}
# {'name': 'Jiban Jyoti Mohanty', 'age': 22, 'city': 'Cuttack'}

# %%
student["name"] = "Rikul"
print(student)
print(student2)
# Out:
# {'name': 'Rikul', 'age': 22, 'city': 'Cuttack'}
# {'name': 'Rikul', 'age': 22, 'city': 'Cuttack'}

# %%
student3 = student.copy()
print(student)
print(student3)
# Out:
# {'name': 'Rikul', 'age': 22, 'city': 'Cuttack'}
# {'name': 'Rikul', 'age': 22, 'city': 'Cuttack'}

# %%
student["name"] = "Jiban Jyoti Mohanty"
print(student)
print(student3)
# Out:
# {'name': 'Jiban Jyoti Mohanty', 'age': 22, 'city': 'Cuttack'}
# {'name': 'Rikul', 'age': 22, 'city': 'Cuttack'}

# %%
for key in student.keys():
    print(key, ":", student[key])
print()
for value in student.values():
    print(value)
# Out:
# name : Jiban Jyoti Mohanty
# age : 22
# city : Cuttack
#
# Jiban Jyoti Mohanty
# 22
# Cuttack

# %%
for key, value in student.items():
    print(key, ":", value)
# Out:
# name : Jiban Jyoti Mohanty
# age : 22
# city : Cuttack
