# %%
print("Hello")
# Out:
# Hello

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
print(fruits)
print(fruits[0])
print(fruits[1])
print(fruits[2])
print(fruits[-1])
print(fruits[-2])
print(fruits[-3])
print(fruits[0:2])
print(fruits[1:])
print(fruits[-1:])
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'mango']
# apple
# banana
# cherry
# mango
# kiwi
# cherry
# ['apple', 'banana']
# ['banana', 'cherry', 'kiwi', 'mango']
# ['mango']

# %%
fruits[3] = "orange"
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'mango']

# %%
fruits[1:] = "watermelon"
print(fruits)
# Out:
# ['apple', 'w', 'a', 't', 'e', 'r', 'm', 'e', 'l', 'o', 'n']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'mango', 'orange']

# %%
fruits.insert(1, "lemon")
print(fruits)
# Out:
# ['apple', 'lemon', 'lemon', 'banana', 'cherry', 'kiwi', 'mango', 'orange']

# %%
fruits.remove("lemon")
print(fruits)
# Out:
# ['apple', 'lemon', 'cherry', 'kiwi', 'mango', 'orange']

# %%
fruits.pop()
print(fruits)
# Out:
# ['apple', 'lemon', 'cherry', 'kiwi', 'mango']

# %%
fruits.insert(1, "banana")
fruits.insert(1, "banana")
print(fruits)
# Out:
# ['apple', 'banana', 'banana', 'banana', 'banana', 'lemon', 'cherry', 'kiwi', 'mango']

# %%
index = fruits.index("banana")
print(index)
print(fruits.count("banana"))
# Out:
# 1
# 4

# %%
fruits.sort()
print(fruits)
fruits.reverse();
print(fruits)
# Out:
# ['apple', 'banana', 'banana', 'banana', 'banana', 'cherry', 'kiwi', 'lemon', 'mango']
# ['mango', 'lemon', 'kiwi', 'cherry', 'banana', 'banana', 'banana', 'banana', 'apple']

# %%
fruits.clear();
print(fruits)
# Out:
# []
