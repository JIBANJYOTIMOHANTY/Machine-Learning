# %%
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a = b
#
# NameError: name 'b' is not defined

# %%
try:
    a = b;
except:
    print("The variable is not assigned.....")
# Out:
# The variable is not assigned.....

# %%
try:
    a = b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
    result = 1 / 0
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the number which is greater than zero")
# Out:
# division by zero
# Please enter the number which is greater than zero

# %%
try:
    result = 1 /2
    a = b;
except ZeroDivisionError as ex:
    print(ex)
except Exception as ex1:
    print(ex1)
# Out:
# name 'b' is not defined

# %%
try:
    num = int(input("Enter a number : "))
    result = 10 / num;
    print(f"{num} is a valid number.")
except ValueError as ve:
    print("This is not a valid number...")
except ZeroDivisionError as zde:
    print("Enter the number which is greater than 0.")
# Out:
# This is not a valid number...

# %%
try:
    num = input("Enter a number : ")
    num1 = int(num)
    result = int(10 / num1);
except ValueError:
    print(f"{num} is not a valid number")
except ZeroDivisionError:
    print(f"You can't divide the 10 by 0")
except Exception as ex:
    print(ex)
else :
    print(f"The result is : {result}")
# Out:
# You can't divide the 10 by 0

# %%
try:
    num = input("Enter a number : ")
    num1 = int(num)
    result = int(10 / num1);
except ValueError:
    print(f"{num} is not a valid number")
except ZeroDivisionError:
    print(f"You can't divide the 10 by 0")
except Exception as ex:
    print(ex)
else :
    print(f"The result is : {result}")
finally:
    print("Execution was completed.")
# Out:
# You can't divide the 10 by 0
# Execution was completed.

# %%
try:
    file = open('example.txt', 'r')
    content = file.read()
    print(content)
except FileNotFoundError:
    print("The File Not Exist !!!")
except Exception as ex:
    print(ex)

finally:
    if 'file' in locals() or not file.closed():
        file.close()
        print("File closed.")
# Out:
# Hello, How are you?
# I am fine.
# What's about you.
# I'm also fine.
# File closed.
