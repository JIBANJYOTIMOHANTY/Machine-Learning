# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt, pi
print(sqrt(25))
print(pi)
# Out:
# 5.0
# 3.141592653589793

# %%
import numpy as np
np.array([1, 2, 3])
# Out:
# array([1, 2, 3])

# %%
from math import *
print(sqrt(25))
print(pi)
# Out:
# 5.0
# 3.141592653589793

# %%
from package.maths import addition
addition(1, 2)
# Out:
# 3

# %%
from package import maths
maths.addition(1, 2)
# Out:
# 3
