# %%
import array
arr = array.array('i', [1, 2, 3, 4, 5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math
print(math.sqrt(100))
print(math.pi)
# Out:
# 10.0
# 3.141592653589793

# %%
import random
print(random.randint(1, 10))
print(random.choice(["apple", "banana", "cherry"]))
# Out:
# 9
# cherry

# %%
import os
print(os.getcwd())
# os.mkdir("new_directory") It will create a new directory named "new_directory"
# Out:
# d:\Machine Learning\python\modules and packages

# %%
import shutil
shutil.copy("source.txt", "destination.txt")
# Out:
# 'destination.txt'

# %%
import json
data = {
    "name" : "Jiban Jyoti Mohanty",
    "age" : 22,
    "city" : "Cuttack"
}
json_string = json.dumps(data)
print(json_string)
print(type(json_string))

parsed_data = json.loads(json_string)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Jiban Jyoti Mohanty", "age": 22, "city": "Cuttack"}
# <class 'str'>
# {'name': 'Jiban Jyoti Mohanty', 'age': 22, 'city': 'Cuttack'}
# <class 'dict'>

# %%
import csv

with open('example.csv', mode = 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Name, Age, City"])
    writer.writerow(["Jiban Jyoti Mohanty", 22, "Cuttack"])
    
with open('example.csv', mode = 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name, Age, City']
# ['Jiban Jyoti Mohanty', '22', 'Cuttack']

# %%
from datetime import datetime, timedelta
now = datetime.now()
print(now)

yesterday = now-timedelta(days=1)
print(yesterday)
# Out:
# 2025-04-21 19:40:54.186004
# 2025-04-20 19:40:54.186004

# %%
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1745244718.833924
# 1745244720.8349497

# %%
import re
pattern = r'\d+'
text = "There are 2 apples and 3 oranges."
matches = re.search(pattern, text)
print(matches.group())
# Out:
# 2
