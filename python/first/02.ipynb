# %%
age = 23;
print(type(age))

age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 23
# <class 'str'>

# %%
age = '25'
print(type(age))
print(type(int(age)))
# Out:
# <class 'str'>
# <class 'int'>

# %%
name = 'jiban'
print(name)
int(name)
# Out:
# jiban
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 name = 'jiban'
#       2 print(name)
# ----> 3 int(name)
#
# ValueError: invalid literal for int() with base 10: 'jiban'

# %%
height = 5.5
type(height)
print(height)
# Out:
# 5.5

# %%
int(height)
# Out:
# 5

# %%
float(int(height))
# Out:
# 5.0

# %%
var = 10;
print(var, type(var))

var = "hello"
print(var, type(var))

var = 3.14
print(var, type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 3.14 <class 'float'>

# %%
age = int(input("what is your age : "))
print(age, type(age))
# Out:
# 22 <class 'int'>
